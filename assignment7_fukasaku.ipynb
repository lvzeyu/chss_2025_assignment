# %% [markdown]
# <a href="https://colab.research.google.com/github/FukasakuRino/chss_2025_assignment/blob/rino/assignment7_fukasaku.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment7
#
# そのまま課題ファイルで編集しないでください。課題ファイルを複製してから課題を回答してください。

# %% [markdown]
# ## 課題1
#
# pandasでDataフォルダの```example.json```を読み込む。

# %%
import pandas as pd
import urllib.request
from io import StringIO

url = "https://raw.githubusercontent.com/lvzeyu/chss_2025_assignment/refs/heads/main/Assignment7/Data/example.json"

#jsonを読み込む関数
def read_json(url):
    print(url)
    res = urllib.request.urlopen(url)
    res = res.read().decode("utf-8")
    df = pd.read_json(StringIO(res), lines=True)
    return df

#実行
read_json(url)
# Out:
# https://raw.githubusercontent.com/lvzeyu/chss_2025_assignment/refs/heads/main/Assignment7/Data/example.json
#      Name  Price  Model  Power
# 0   Honda  10000   2005   1300
# 1  Toyota  12000   2010   1600
# 2    Audi  25000   2017   1800
# 3    Ford  28000   2009   1200

# %% [markdown]
# ## 課題2
#
# pandasでDataフォルダの```state-abbrevs.csv```、```state-areas.csv```、```state-population.csv```を読み込む。
#
# これらのデータを使って、**2010年**アメリカの各州の人口密度を計算しよう。

# %%
url = ["https://raw.githubusercontent.com/lvzeyu/chss_2025_assignment/refs/heads/main/Assignment7/Data/state-abbrevs.csv",
       "https://raw.githubusercontent.com/lvzeyu/chss_2025_assignment/refs/heads/main/Assignment7/Data/state-areas.csv",
       "https://raw.githubusercontent.com/lvzeyu/chss_2025_assignment/refs/heads/main/Assignment7/Data/state-population.csv"]

def read_csv(url_list):
    dataframes = []
    for url in url_list:
        print(url)
        res = urllib.request.urlopen(url)
        res = res.read().decode("utf-8")
        df = pd.read_csv(StringIO(res))
        dataframes.append(df)
    return dataframes

display(abbrevs_df.head(),areas_df.head(), population_df.head())
# Out:
#         state abbreviation
# 0     Alabama           AL
# 1      Alaska           AK
# 2     Arizona           AZ
# 3    Arkansas           AR
# 4  California           CA
#         state  area (sq. mi)
# 0     Alabama          52423
# 1      Alaska         656425
# 2     Arizona         114006
# 3    Arkansas          53182
# 4  California         163707
#   state/region     ages  year  population
# 0           AL  under18  2012   1117489.0
# 1           AL    total  2012   4817528.0
# 2           AL  under18  2010   1130966.0
# 3           AL    total  2010   4785570.0
# 4           AL  under18  2011   1125763.0

# %%
df1 = pd.merge(abbrevs_df, areas_df)
df2 = population_df[(population_df["year"]==2010) & (population_df["ages"]=="total")]
df3 = pd.merge(df1, df2, left_on='abbreviation', right_on='state/region')
df3["density"] = df3['population']/df3['area (sq. mi)']
display(df1.head(), df2.head(),df3.head())
# Out:
#         state abbreviation  area (sq. mi)
# 0     Alabama           AL          52423
# 1      Alaska           AK         656425
# 2     Arizona           AZ         114006
# 3    Arkansas           AR          53182
# 4  California           CA         163707
#     state/region   ages  year  population
# 3             AL  total  2010   4785570.0
# 91            AK  total  2010    713868.0
# 101           AZ  total  2010   6408790.0
# 189           AR  total  2010   2922280.0
# 197           CA  total  2010  37333601.0
#         state abbreviation  area (sq. mi) state/region   ages  year  \
# 0     Alabama           AL          52423           AL  total  2010
# 1      Alaska           AK         656425           AK  total  2010
# 2     Arizona           AZ         114006           AZ  total  2010
# 3    Arkansas           AR          53182           AR  total  2010
# 4  California           CA         163707           CA  total  2010
#
#    population     density
# ...

# %% [markdown]
# ## 課題3
#
# ```state/region```、```ages```と```years```でデータフレームをグループして、各グループで$\frac{population}{area (sq. mi)}$の形で人口密度を計算してください。

# %%
df5 = pd.merge(df1, population_df, left_on='abbreviation', right_on='state/region')
df5["density1"] = df5["population"]/df5["area (sq. mi)"]
#state/regionごとにグループ化する
density1 = df5.groupby("state/region")["density1"].mean()
#agesごとにグループ化する
density2 = df5.groupby("ages")["density1"].mean()
#yearごとにグループ化する
density3 = df5.groupby("year")["density1"].mean()

display(density1, density2, density3)
# Out:
# state/region
# AK       0.634404
# AL      53.370896
# AR      31.714490
# AZ      29.275452
# CA     132.609349
# CO      26.203680
# CT     383.918140
# DC    5141.960478
# DE     254.820934
# FL     153.336900
# GA      88.918774
# HI      71.178555
# IA      32.550085
# ID      10.261864
# IL     133.942860
# IN     105.392094
# KS      20.704030
# KY      62.765026
# LA      54.232430
# MA     368.658168
# MD     270.613563
# ME      22.343946
# MI      63.606122
# MN      35.753596
# MO      50.529093
# MS      37.045936
# MT       3.887257
# NC      95.515220
# ND       5.751817
# NE      14.063723
# NH      82.086515
# NJ     599.295266
# NM       9.665614
# NV      11.850542
# NY     215.012775
# OH     157.920909
# OK      31.358060
# OR      21.821400
# PA     165.351631
# RI     413.618811
# SC      80.285658
# SD       6.276215
# TN      84.922783
# TX      51.442757
# UT      18.091122
# VA     105.079932
# VT      38.851985
# WA      52.560699
# WI      51.466759
# ...
